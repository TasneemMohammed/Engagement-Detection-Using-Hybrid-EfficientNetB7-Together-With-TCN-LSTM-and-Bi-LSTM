# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np

from tensorflow.keras.applications import EfficientNetB7

import tensorflow.keras
from tensorflow.keras import applications
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *

# %%
train_video_path = '/content/drive/MyDrive/4levelClassification/batches/'
saved_nparray_path = '/content/drive/MyDrive/4levelClassification/train_nparray/data/' #this path will be deleted if we have good resources
train_nparray_path = '/content/drive/MyDrive/4levelClassification/train_nparray/'

img_height , img_width = 600, 600  # dimension of each frame in video
seq_len = 60 #the number of images we pass as one sequence (only 70 frames per video) -more frames/ better results/ computationally expensive

classes = [0, 1, 2, 3]

# %%
def conv_base():
    feature_extractor =  tensorflow.keras.applications.EfficientNetB7(input_shape=(img_height,img_width,3),
                              include_top=False, weights='imagenet',pooling="avg")

    preprocess_input = tensorflow.keras.applications.efficientnet.preprocess_input
    inputs = tensorflow.keras.Input((img_height, img_width, 3))
    preprocessed = preprocess_input(inputs)

    outputs = feature_extractor(preprocessed)
    return tensorflow.keras.Model(inputs, outputs, name="conv_base")

conv_base = conv_base()
conv_base.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258080768/258076736 [==============================] - 2s 0us/step
# 258088960/258076736 [==============================] - 2s 0us/step
# Model: "conv_base"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 600, 600, 3)]     0
#
#  efficientnetb7 (Functional)  (None, 2560)             64097687
#
# =================================================================
# Total params: 64,097,687
# Trainable params: 63,786,960
# Non-trainable params: 310,727
# _________________________________________________________________

# %%
part1=0
part2=60
part3=120
part4=180
part5=240
currentPart = -1
def frames_extraction(video_path):

    frames_list = []

    #creating an object by capturing the given video
    #This object can be used to read frames from the captured video
    vidObj = cv2.VideoCapture(video_path)

    #Counter variable - will be incrementing upto the seq_len
    seqCount = 1
    #skipCount = 2
    defect = 0
    successCount = 0
    start = 0

    #The count variable ensures that the number of extracted frames should be equal to the seq_len
    while seqCount <= seq_len:

        #Reading one frame at a time from the video, it returns status (success) and the actual frame (image)
        success, image = vidObj.read()
        #print(success)
        #If it is not able to read the frame properly then success = 0, and code will jump to else part
        #if success and skipCount == 0:
        if success and start>=currentPart:
            image = cv2.resize(image, (img_height, img_width))
            frames_list.append(image)
            seqCount += 1
            #skipCount = 2
            successCount += 1


        elif success and start<currentPart:
            start +=1
        #elif skipCount > 0:
        #  skipCount -= 1

        elif (defect + seqCount) >=300:
          break

        else:
            '''Defect frame will not be added to list of frames and if number of extracted frames is less than the seq_len, video will be rejected, in next section'''
            defect += 1
            print("Defected frame at ", defect, " ", video_path)

    print(start)
    print("Defected", defect)
    print("successCount", successCount)
    frames = np.asarray(frames_list)
    vidObj.release()
    return frames

# %%
def create_Data(batch_dir):
    X = []
    Y = []

    classes_list = os.listdir(batch_dir)
    print(classes_list)

    for c in classes_list:
        print(c)
        # creating the list of videos for the current class
        files_list = os.listdir(os.path.join(batch_dir, c))
        # we’ll pass videos one by one for frames extraction
        for f in files_list:
            #extracting the frames from the given video
            video_path = (os.path.join(os.path.join(batch_dir, c), f))
            #print(video_path)
            frames = frames_extraction(video_path)
            # Check whether the number of frames is equal to the seq_len, if yes -> process, otherwise reject the current video
            if len(frames) == seq_len:
                print(np.asarray(frames).shape)
                #appending the sequence of frames to the input list X
                X.append(conv_base.predict(frames))
                #X.append(frames)
                #we are creating one hot encoding for target variable
                #create the list y of length number of classes, where each element is 0
                y = [0]*len(classes)
                #We find the index of current class c in the classes list and making corresponding element 1 in y
                y[classes.index(int(c))] = 1
                #Now we append the list y into Y
                Y.append(y)

    X = np.asarray(X)
    Y = np.asarray(Y)
    return X, Y

# %%
currentPart = part1
batches_list = os.listdir(train_video_path)
print(batches_list)
saved_batches = os.listdir(saved_nparray_path) #no need for this if we have good reources
print(saved_batches)
counter = 0
for batch in batches_list:
        if batch+".npy" in saved_batches: #no need for the if we have no resources
          skippedBatch = np.load(os.path.join(train_nparray_path, "data" , batch+".npy"))
          print(batch, "skipped", skippedBatch.shape)
          continue
        print(batch)
        x_batch, y_batch = create_Data(os.path.join(train_video_path, batch))
        x_batch = np.asarray(x_batch)
        y_batch = np.asarray(y_batch)
        np.save(os.path.join(train_nparray_path, "data", batch), x_batch)
        np.save(os.path.join(train_nparray_path, "label", batch), y_batch)

        counter += 1
        print(counter)
# Out:
# ['Batch1', 'Batch2', 'Batch3', 'Batch4', 'Batch5', 'Batch6', 'Batch7', 'Batch8', 'Batch9', 'Batch10', 'Batch11', 'Batch12', 'Batch13', 'Batch14', 'Batch15', 'Batch16', 'Batch17', 'Batch18', 'Batch19', 'Batch20', 'Batch21', 'Batch22', 'Batch23', 'Batch25', 'Batch26', 'Batch24', 'Batch27', 'Batch28', 'Batch29', 'Batch30', 'Batch31', 'Batch32', 'Batch33', 'Batch35', 'Batch37', 'Batch34', 'Batch36', 'Batch38', 'Batch39', 'Batch40', 'Batch41', 'Batch43', 'Batch42', 'Batch44', 'Batch45', 'Batch46', 'Batch50', 'Batch49', 'Batch48', 'Batch47', 'Batch51', 'Batch52', 'Batch53', 'Batch54', 'Batch55', 'Batch56', 'Batch57', 'Batch58', 'Batch59', 'Batch60', 'Batch61', 'Batch66', 'Batch65', 'Batch64', 'Batch63', 'Batch62', 'Batch67', 'Batch68', 'Batch69', 'Batch70', 'Batch73', 'Batch71', 'Batch72', 'Batch74', 'Batch75', 'Batch77', 'Batch78', 'Batch79', 'Batch80', 'Batch76', 'Batch81', 'Batch82', 'Batch83', 'Batch84', 'Batch85', 'Batch86', 'Batch87', 'Batch88', 'Batch89', 'Batch90', 'Batch91', 'Batch92', 'Batch95', 'Batch93', 'Batch94', 'Batch96', 'Batch100', 'Batch99', 'Batch98', 'Batch97', 'Batch101', 'Batch102', 'Batch103', 'Batch104', 'Batch105', 'Batch106', 'Batch107', 'Batch108', 'Batch109', 'Batch110', 'Batch111', 'Batch112', 'Batch113', 'Batch114', 'Batch115', 'Batch116', 'Batch117', 'Batch118', 'Batch119', 'Batch120', 'Batch121', 'Batch122', 'Batch123', 'Batch125', 'Batch124', 'Batch126', 'Batch127', 'Batch128', 'Batch129', 'Batch130', 'Batch131', 'Batch132', 'Batch133', 'Batch134', 'Batch135', 'Batch136', 'Batch137', 'Batch140', 'Batch139', 'Batch138', 'Batch141', 'Batch142', 'Batch143', 'Batch144', 'Batch145', 'Batch146', 'Batch166', 'Batch163', 'Batch165', 'Batch150', 'Batch156', 'Batch164', 'Batch158', 'Batch157', 'Batch152', 'Batch162', 'Batch161', 'Batch147', 'Batch148', 'Batch149', 'Batch151', 'Batch153', 'Batch154', 'Batch155', 'Batch159', 'Batch160']
# Batch12 skipped (32, 60, 2560)
# Batch13 skipped (32, 60, 2560)
# Batch14 skipped (32, 60, 2560)
# Batch15 skipped (32, 60, 2560)
# Batch16 skipped (32, 60, 2560)
# Batch17 skipped (32, 60, 2560)
# Batch18 skipped (32, 60, 2560)
# Batch19 skipped (32, 60, 2560)
# Batch20 skipped (32, 60, 2560)
# Batch21 skipped (32, 60, 2560)
# Batch22 skipped (32, 60, 2560)
# Batch23 skipped (32, 60, 2560)
# Batch25 skipped (32, 60, 2560)
# Batch26 skipped (32, 60, 2560)
# Batch24 skipped (32, 60, 2560)
# Batch27 skipped (32, 60, 2560)
# Batch28 skipped (32, 60, 2560)
# Batch29 skipped (32, 60, 2560)
# Batch30 skipped (32, 60, 2560)
# Batch31 skipped (32, 60, 2560)
# Batch32 skipped (32, 60, 2560)
# Batch33 skipped (32, 60, 2560)
# Batch35 skipped (32, 60, 2560)
# Batch37 skipped (32, 60, 2560)
# Batch34 skipped (32, 60, 2560)
# Batch36 skipped (32, 60, 2560)
# Batch38 skipped (32, 60, 2560)
# Batch39 skipped (32, 60, 2560)
# Batch40 skipped (32, 60, 2560)
# Batch41 skipped (32, 60, 2560)
# Batch43 skipped (32, 60, 2560)
# Batch42 skipped (32, 60, 2560)
# Batch44 skipped (32, 60, 2560)
# Batch45 skipped (32, 60, 2560)
# Batch46 skipped (32, 60, 2560)
# Batch50 skipped (32, 60, 2560)
# Batch49 skipped (32, 60, 2560)
# Batch48 skipped (32, 60, 2560)
# Batch47 skipped (32, 60, 2560)
# Batch51 skipped (32, 60, 2560)
# Batch52 skipped (32, 60, 2560)
# Batch53 skipped (32, 60, 2560)
# Batch54 skipped (32, 60, 2560)
# Batch55 skipped (32, 60, 2560)
# Batch56 skipped (32, 60, 2560)
# Batch57 skipped (32, 60, 2560)
# Batch58 skipped (32, 60, 2560)
# Batch59 skipped (32, 60, 2560)
# Batch60 skipped (32, 60, 2560)
# Batch61 skipped (32, 60, 2560)
# Batch66 skipped (32, 60, 2560)
# Batch65 skipped (32, 60, 2560)
# Batch64 skipped (32, 60, 2560)
# Batch63 skipped (32, 60, 2560)
# Batch62 skipped (32, 60, 2560)
# Batch67 skipped (32, 60, 2560)
# Batch68 skipped (32, 60, 2560)
# Batch69 skipped (32, 60, 2560)
# Batch70 skipped (32, 60, 2560)
# Batch73 skipped (32, 60, 2560)
# Batch71 skipped (32, 60, 2560)
# Batch72 skipped (32, 60, 2560)
# Batch74 skipped (32, 60, 2560)
# Batch75 skipped (32, 60, 2560)
# Batch77 skipped (32, 60, 2560)
# Batch78 skipped (32, 60, 2560)
# Batch79 skipped (32, 60, 2560)
# Batch80 skipped (32, 60, 2560)
# Batch76 skipped (32, 60, 2560)
# Batch81 skipped (32, 60, 2560)
# Batch82 skipped (32, 60, 2560)
# Batch83 skipped (32, 60, 2560)
# Batch84 skipped (32, 60, 2560)
# Batch85 skipped (32, 60, 2560)
# Batch86 skipped (32, 60, 2560)
# Batch87 skipped (32, 60, 2560)
# Batch88 skipped (32, 60, 2560)
# Batch89 skipped (32, 60, 2560)
# Batch90 skipped (32, 60, 2560)
# Batch91 skipped (32, 60, 2560)
# Batch92 skipped (32, 60, 2560)
# Batch95 skipped (32, 60, 2560)
# Batch93 skipped (32, 60, 2560)
# Batch94 skipped (32, 60, 2560)
# Batch96 skipped (32, 60, 2560)
# Batch100 skipped (32, 60, 2560)
# Batch99 skipped (32, 60, 2560)
# Batch98 skipped (32, 60, 2560)
# Batch97 skipped (32, 60, 2560)
# Batch101 skipped (32, 60, 2560)
# Batch102 skipped (32, 60, 2560)
# Batch103 skipped (32, 60, 2560)
# Batch104 skipped (32, 60, 2560)
# Batch105 skipped (32, 60, 2560)
# Batch106 skipped (32, 60, 2560)
# Batch107 skipped (32, 60, 2560)
# Batch108 skipped (32, 60, 2560)
# Batch109 skipped (32, 60, 2560)
# Batch110 skipped (32, 60, 2560)
# Batch111 skipped (32, 60, 2560)
# Batch112 skipped (32, 60, 2560)
# Batch113 skipped (32, 60, 2560)
# Batch114 skipped (32, 60, 2560)
# Batch115 skipped (32, 60, 2560)
# Batch116 skipped (32, 60, 2560)
# Batch117 skipped (32, 60, 2560)
# Batch118 skipped (32, 60, 2560)
# Batch119 skipped (32, 60, 2560)
# Batch120 skipped (32, 60, 2560)
# Batch121 skipped (32, 60, 2560)
# Batch122 skipped (32, 60, 2560)
# Batch123 skipped (32, 60, 2560)
# Batch125 skipped (32, 60, 2560)
# Batch124 skipped (32, 60, 2560)
# Batch126 skipped (32, 60, 2560)
# Batch127 skipped (32, 60, 2560)
# Batch128 skipped (32, 60, 2560)
# Batch129 skipped (32, 60, 2560)
# Batch130 skipped (32, 60, 2560)
# Batch131 skipped (32, 60, 2560)
# Batch132 skipped (32, 60, 2560)
# Batch133 skipped (32, 60, 2560)
# Batch134 skipped (32, 60, 2560)
# Batch135 skipped (32, 60, 2560)
# Batch136 skipped (32, 60, 2560)
# Batch137 skipped (32, 60, 2560)
# Batch140 skipped (32, 60, 2560)
# Batch139 skipped (32, 60, 2560)
# Batch138 skipped (32, 60, 2560)
# Batch141 skipped (32, 60, 2560)
# Batch142 skipped (32, 60, 2560)
# Batch143 skipped (32, 60, 2560)
# Batch144 skipped (32, 60, 2560)
# Batch145 skipped (32, 60, 2560)
# Batch146 skipped (32, 60, 2560)
# Batch166 skipped (32, 60, 2560)
# Batch163 skipped (32, 60, 2560)
# Batch165 skipped (32, 60, 2560)
# Batch150 skipped (32, 60, 2560)
# Batch156 skipped (32, 60, 2560)
# Batch164 skipped (32, 60, 2560)
# Batch158 skipped (32, 60, 2560)
# Batch157 skipped (32, 60, 2560)
# Batch152 skipped (32, 60, 2560)
# Batch162 skipped (32, 60, 2560)
# Batch161 skipped (32, 60, 2560)
# Batch147 skipped (32, 60, 2560)
# Batch148 skipped (32, 60, 2560)
# Batch149 skipped (32, 60, 2560)
# Batch151 skipped (32, 60, 2560)
# Batch153 skipped (32, 60, 2560)
# Batch154 skipped (32, 60, 2560)
# Batch155 skipped (32, 60, 2560)
# Batch159 skipped (32, 60, 2560)
# Batch160 skipped (32, 60, 2560)

# %%
currentPart = part2
batches_list = os.listdir(train_video_path)
print(batches_list)
saved_batches = os.listdir(saved_nparray_path) #no need for this if we have good reources
print(saved_batches)
counter = 0
for batch in batches_list:
        if batch+"Dup1.npy" in saved_batches: #no need for the if we have no resources
          skippedBatch = np.load(os.path.join(train_nparray_path, "data" , batch+".npy"))
          print(batch, "Dup1 skipped", skippedBatch.shape)
          continue
        print(batch)
        x_batch, y_batch = create_Data(os.path.join(train_video_path, batch))
        x_batch = np.asarray(x_batch)
        y_batch = np.asarray(y_batch)
        np.save(os.path.join(train_nparray_path, "data", batch+"Dup1"), x_batch)
        np.save(os.path.join(train_nparray_path, "label", batch+"Dup1"), y_batch)

        counter += 1
        print(counter)
# Out:
# ['Batch1', 'Batch2', 'Batch3', 'Batch4', 'Batch5', 'Batch6', 'Batch7', 'Batch8', 'Batch9', 'Batch10', 'Batch11', 'Batch12', 'Batch13', 'Batch14', 'Batch15', 'Batch16', 'Batch17', 'Batch18', 'Batch19', 'Batch20', 'Batch21', 'Batch22', 'Batch23', 'Batch25', 'Batch26', 'Batch24', 'Batch27', 'Batch28', 'Batch29', 'Batch30', 'Batch31', 'Batch32', 'Batch33', 'Batch35', 'Batch37', 'Batch34', 'Batch36', 'Batch38', 'Batch39', 'Batch40', 'Batch41', 'Batch43', 'Batch42', 'Batch44', 'Batch45', 'Batch46', 'Batch50', 'Batch49', 'Batch48', 'Batch47', 'Batch51', 'Batch52', 'Batch53', 'Batch54', 'Batch55', 'Batch56', 'Batch57', 'Batch58', 'Batch59', 'Batch60', 'Batch61', 'Batch66', 'Batch65', 'Batch64', 'Batch63', 'Batch62', 'Batch67', 'Batch68', 'Batch69', 'Batch70', 'Batch73', 'Batch71', 'Batch72', 'Batch74', 'Batch75', 'Batch77', 'Batch78', 'Batch79', 'Batch80', 'Batch76', 'Batch81', 'Batch82', 'Batch83', 'Batch84', 'Batch85', 'Batch86', 'Batch87', 'Batch88', 'Batch89', 'Batch90', 'Batch91', 'Batch92', 'Batch95', 'Batch93', 'Batch94', 'Batch96', 'Batch100', 'Batch99', 'Batch98', 'Batch97', 'Batch101', 'Batch102', 'Batch103', 'Batch104', 'Batch105', 'Batch106', 'Batch107', 'Batch108', 'Batch109', 'Batch110', 'Batch111', 'Batch112', 'Batch113', 'Batch114', 'Batch115', 'Batch116', 'Batch117', 'Batch118', 'Batch119', 'Batch120', 'Batch121', 'Batch122', 'Batch123', 'Batch125', 'Batch124', 'Batch126', 'Batch127', 'Batch128', 'Batch129', 'Batch130', 'Batch131', 'Batch132', 'Batch133', 'Batch134', 'Batch135', 'Batch136', 'Batch137', 'Batch140', 'Batch139', 'Batch138', 'Batch141', 'Batch142', 'Batch143', 'Batch144', 'Batch145', 'Batch146', 'Batch166', 'Batch163', 'Batch165', 'Batch150', 'Batch156', 'Batch164', 'Batch158', 'Batch157', 'Batch152', 'Batch162', 'Batch161', 'Batch147', 'Batch148', 'Batch149', 'Batch151', 'Batch153', 'Batch154', 'Batch155', 'Batch159', 'Batch160']
'Batch156.npy', 'Batch164.npy', 'Batch158.npy', 'Batch157.npy', 'Batch152.npy', 'Batch162.npy', 'Batch161.npy', 'Batch147.npy', 'Batch148.npy', 'Batch149.npy', 'Batch151.npy', 'Batch153.npy', 'Batch154.npy', 'Batch155.npy', 'Batch159.npy', 'Batch160.npy', 'Batch1Dup1.npy', 'Batch2Dup1.npy', 'Batch3Dup1.npy', 'Batch4Dup1.npy', 'Batch5Dup1.npy', 'Batch6Dup1.npy', 'Batch7Dup1.npy', 'Batch8Dup1.npy', 'Batch9Dup1.npy', 'Batch10Dup1.npy', 'Batch11Dup1.npy', 'Batch12Dup1.npy', 'Batch13Dup1.npy', 'Batch14Dup1.npy', 'Batch15Dup1.npy', 'Batch16Dup1.npy', 'Batch17Dup1.npy', 'Batch18Dup1.npy', 'Batch19Dup1.npy', 'Batch20Dup1.npy', 'Batch21Dup1.npy', 'Batch22Dup1.npy', 'Batch23Dup1.npy', 'Batch25Dup1.npy', 'Batch26Dup1.npy', 'Batch24Dup1.npy', 'Batch27Dup1.npy', 'Batch28Dup1.npy', 'Batch29Dup1.npy', 'Batch30Dup1.npy', 'Batch31Dup1.npy', 'Batch32Dup1.npy', 'Batch33Dup1.npy', 'Batch35Dup1.npy', 'Batch37Dup1.npy', 'Batch34Dup1.npy', 'Batch36Dup1.npy', 'Batch38Dup1.npy', 'Batch39Dup1.npy', 'Batch40Dup1.npy', 'Batch41Dup1.npy', 'Batch43Dup1.npy', 'Batch42Dup1.npy', 'Batch44Dup1.npy', 'Batch45Dup1.npy', 'Batch46Dup1.npy', 'Batch50Dup1.npy', 'Batch49Dup1.npy', 'Batch48Dup1.npy', 'Batch47Dup1.npy', 'Batch51Dup1.npy', 'Batch52Dup1.npy', 'Batch53Dup1.npy', 'Batch54Dup1.npy', 'Batch55Dup1.npy', 'Batch56Dup1.npy', 'Batch57Dup1.npy', 'Batch58Dup1.npy', 'Batch59Dup1.npy', 'Batch60Dup1.npy', 'Batch61Dup1.npy', 'Batch66Dup1.npy', 'Batch65Dup1.npy', 'Batch64Dup1.npy', 'Batch63Dup1.npy', 'Batch62Dup1.npy', 'Batch67Dup1.npy', 'Batch68Dup1.npy', 'Batch69Dup1.npy', 'Batch70Dup1.npy', 'Batch73Dup1.npy', 'Batch71Dup1.npy', 'Batch72Dup1.npy', 'Batch74Dup1.npy', 'Batch75Dup1.npy', 'Batch77Dup1.npy', 'Batch78Dup1.npy ...
# Batch1 Dup1 skipped (32, 60, 2560)
# Batch2 Dup1 skipped (32, 60, 2560)
# Batch3 Dup1 skipped (32, 60, 2560)
# Batch4 Dup1 skipped (32, 60, 2560)
# Batch5 Dup1 skipped (32, 60, 2560)
# Batch6 Dup1 skipped (32, 60, 2560)
# Batch7 Dup1 skipped (32, 60, 2560)
# Batch8 Dup1 skipped (32, 60, 2560)
# Batch9 Dup1 skipped (32, 60, 2560)
# Batch10 Dup1 skipped (32, 60, 2560)
# Batch11 Dup1 skipped (32, 60, 2560)
# Batch12 Dup1 skipped (32, 60, 2560)
# Batch13 Dup1 skipped (32, 60, 2560)
# Batch14 Dup1 skipped (32, 60, 2560)
# Batch15 Dup1 skipped (32, 60, 2560)
# Batch16 Dup1 skipped (32, 60, 2560)
# Batch17 Dup1 skipped (32, 60, 2560)
# Batch18 Dup1 skipped (32, 60, 2560)
# Batch19 Dup1 skipped (32, 60, 2560)
# Batch20 Dup1 skipped (32, 60, 2560)
# Batch21 Dup1 skipped (32, 60, 2560)
# Batch22 Dup1 skipped (32, 60, 2560)
# Batch23 Dup1 skipped (32, 60, 2560)
# Batch25 Dup1 skipped (32, 60, 2560)
# Batch26 Dup1 skipped (32, 60, 2560)
# Batch24 Dup1 skipped (32, 60, 2560)
# Batch27 Dup1 skipped (32, 60, 2560)
# Batch28 Dup1 skipped (32, 60, 2560)
# Batch29 Dup1 skipped (32, 60, 2560)
# Batch30 Dup1 skipped (32, 60, 2560)
# Batch31 Dup1 skipped (32, 60, 2560)
# Batch32 Dup1 skipped (32, 60, 2560)
# Batch33 Dup1 skipped (32, 60, 2560)
# Batch35 Dup1 skipped (32, 60, 2560)
# Batch37 Dup1 skipped (32, 60, 2560)
# Batch34 Dup1 skipped (32, 60, 2560)
# Batch36 Dup1 skipped (32, 60, 2560)
# Batch38 Dup1 skipped (32, 60, 2560)
# Batch39 Dup1 skipped (32, 60, 2560)
# Batch40 Dup1 skipped (32, 60, 2560)
# Batch41 Dup1 skipped (32, 60, 2560)
# Batch43 Dup1 skipped (32, 60, 2560)
# Batch42 Dup1 skipped (32, 60, 2560)
# Batch44 Dup1 skipped (32, 60, 2560)
# Batch45 Dup1 skipped (32, 60, 2560)
# Batch46 Dup1 skipped (32, 60, 2560)
# Batch50 Dup1 skipped (32, 60, 2560)
# Batch49 Dup1 skipped (32, 60, 2560)
# Batch48 Dup1 skipped (32, 60, 2560)
# Batch47 Dup1 skipped (32, 60, 2560)
# Batch51 Dup1 skipped (32, 60, 2560)
# Batch52 Dup1 skipped (32, 60, 2560)
# Batch53 Dup1 skipped (32, 60, 2560)
# Batch54 Dup1 skipped (32, 60, 2560)
# Batch55 Dup1 skipped (32, 60, 2560)
# Batch56 Dup1 skipped (32, 60, 2560)
# Batch57 Dup1 skipped (32, 60, 2560)
# Batch58 Dup1 skipped (32, 60, 2560)
# Batch59 Dup1 skipped (32, 60, 2560)
# Batch60 Dup1 skipped (32, 60, 2560)
# Batch61 Dup1 skipped (32, 60, 2560)
# Batch66 Dup1 skipped (32, 60, 2560)
# Batch65 Dup1 skipped (32, 60, 2560)
# Batch64 Dup1 skipped (32, 60, 2560)
# Batch63 Dup1 skipped (32, 60, 2560)
# Batch62 Dup1 skipped (32, 60, 2560)
# Batch67 Dup1 skipped (32, 60, 2560)
# Batch68 Dup1 skipped (32, 60, 2560)
# Batch69 Dup1 skipped (32, 60, 2560)
# Batch70 Dup1 skipped (32, 60, 2560)
# Batch73 Dup1 skipped (32, 60, 2560)
# Batch71 Dup1 skipped (32, 60, 2560)
# Batch72 Dup1 skipped (32, 60, 2560)
# Batch74 Dup1 skipped (32, 60, 2560)
# Batch75 Dup1 skipped (32, 60, 2560)
# Batch77 Dup1 skipped (32, 60, 2560)
# Batch78 Dup1 skipped (32, 60, 2560)
# Batch79 Dup1 skipped (32, 60, 2560)
# Batch80 Dup1 skipped (32, 60, 2560)
# Batch76 Dup1 skipped (32, 60, 2560)
# Batch81 Dup1 skipped (32, 60, 2560)
# Batch82 Dup1 skipped (32, 60, 2560)
# Batch83 Dup1 skipped (32, 60, 2560)
# Batch84 Dup1 skipped (32, 60, 2560)
# Batch85 Dup1 skipped (32, 60, 2560)
# Batch86 Dup1 skipped (32, 60, 2560)
# Batch87 Dup1 skipped (32, 60, 2560)
# Batch88 Dup1 skipped (32, 60, 2560)
# Batch89 Dup1 skipped (32, 60, 2560)
# Batch90 Dup1 skipped (32, 60, 2560)
# Batch91 Dup1 skipped (32, 60, 2560)
# Batch92 Dup1 skipped (32, 60, 2560)
# Batch95 Dup1 skipped (32, 60, 2560)
# Batch93 Dup1 skipped (32, 60, 2560)
# Batch94 Dup1 skipped (32, 60, 2560)
# Batch96 Dup1 skipped (32, 60, 2560)
# Batch100 Dup1 skipped (32, 60, 2560)
# Batch99 Dup1 skipped (32, 60, 2560)
# Batch98 Dup1 skipped (32, 60, 2560)
# Batch97 Dup1 skipped (32, 60, 2560)
# Batch101 Dup1 skipped (32, 60, 2560)
# Batch102 Dup1 skipped (32, 60, 2560)
# Batch103 Dup1 skipped (32, 60, 2560)
# Batch104 Dup1 skipped (32, 60, 2560)
# Batch105 Dup1 skipped (32, 60, 2560)
# Batch106 Dup1 skipped (32, 60, 2560)
# Batch107 Dup1 skipped (32, 60, 2560)
# Batch108 Dup1 skipped (32, 60, 2560)
# Batch109 Dup1 skipped (32, 60, 2560)
# Batch110 Dup1 skipped (32, 60, 2560)
# Batch111 Dup1 skipped (32, 60, 2560)
# Batch112 Dup1 skipped (32, 60, 2560)
# Batch113 Dup1 skipped (32, 60, 2560)
# Batch114 Dup1 skipped (32, 60, 2560)
# Batch115 Dup1 skipped (32, 60, 2560)
# Batch116 Dup1 skipped (32, 60, 2560)
# Batch117 Dup1 skipped (32, 60, 2560)
# Batch118 Dup1 skipped (32, 60, 2560)
# Batch119 Dup1 skipped (32, 60, 2560)
# Batch120 Dup1 skipped (32, 60, 2560)
# Batch121 Dup1 skipped (32, 60, 2560)
# Batch122 Dup1 skipped (32, 60, 2560)
# Batch123 Dup1 skipped (32, 60, 2560)
# Batch125 Dup1 skipped (32, 60, 2560)
# Batch124 Dup1 skipped (32, 60, 2560)
# Batch126 Dup1 skipped (32, 60, 2560)
# Batch127 Dup1 skipped (32, 60, 2560)
# Batch128 Dup1 skipped (32, 60, 2560)
# Batch129 Dup1 skipped (32, 60, 2560)
# Batch130 Dup1 skipped (32, 60, 2560)
# Batch131 Dup1 skipped (32, 60, 2560)
# Batch132 Dup1 skipped (32, 60, 2560)
# Batch133 Dup1 skipped (32, 60, 2560)
# Batch134 Dup1 skipped (32, 60, 2560)
# Batch135 Dup1 skipped (32, 60, 2560)
# Batch136 Dup1 skipped (32, 60, 2560)
# Batch137 Dup1 skipped (32, 60, 2560)
# Batch140 Dup1 skipped (32, 60, 2560)
# Batch139 Dup1 skipped (32, 60, 2560)
# Batch138 Dup1 skipped (32, 60, 2560)
# Batch141 Dup1 skipped (32, 60, 2560)
# Batch142 Dup1 skipped (32, 60, 2560)
# Batch143 Dup1 skipped (32, 60, 2560)
# Batch144 Dup1 skipped (32, 60, 2560)
# Batch145 Dup1 skipped (32, 60, 2560)
# Batch146 Dup1 skipped (32, 60, 2560)
# Batch166 Dup1 skipped (32, 60, 2560)
# Batch163 Dup1 skipped (32, 60, 2560)
# Batch165 Dup1 skipped (32, 60, 2560)
# Batch150 Dup1 skipped (32, 60, 2560)
# Batch156 Dup1 skipped (32, 60, 2560)
# Batch164 Dup1 skipped (32, 60, 2560)
# Batch158 Dup1 skipped (32, 60, 2560)
# Batch157 Dup1 skipped (32, 60, 2560)
# Batch152 Dup1 skipped (32, 60, 2560)
# Batch162 Dup1 skipped (32, 60, 2560)
# Batch161 Dup1 skipped (32, 60, 2560)
# Batch147 Dup1 skipped (32, 60, 2560)
# Batch148 Dup1 skipped (32, 60, 2560)
# Batch149 Dup1 skipped (32, 60, 2560)
# Batch151 Dup1 skipped (32, 60, 2560)
# Batch153 Dup1 skipped (32, 60, 2560)
# Batch154 Dup1 skipped (32, 60, 2560)
# Batch155 Dup1 skipped (32, 60, 2560)
# Batch159 Dup1 skipped (32, 60, 2560)
# Batch160 Dup1 skipped (32, 60, 2560)

# %%
currentPart = part3
batches_list = os.listdir(train_video_path)
print(batches_list)
saved_batches = os.listdir(saved_nparray_path) #no need for this if we have good reources
print(saved_batches)
counter = 0
for batch in batches_list:
        if batch+"Dup2.npy" in saved_batches: #no need for the if we have no resources
          skippedBatch = np.load(os.path.join(train_nparray_path, "data" , batch+".npy"))
          print(batch, "Dup2 skipped", skippedBatch.shape)
          continue
        print(batch)
        x_batch, y_batch = create_Data(os.path.join(train_video_path, batch))
        x_batch = np.asarray(x_batch)
        y_batch = np.asarray(y_batch)
        np.save(os.path.join(train_nparray_path, "data", batch+"Dup2"), x_batch)
        np.save(os.path.join(train_nparray_path, "label", batch+"Dup2"), y_batch)

        counter += 1
        print(counter)
# Out:
# ['Batch1', 'Batch2', 'Batch3', 'Batch4', 'Batch5', 'Batch6', 'Batch7', 'Batch8', 'Batch9', 'Batch10', 'Batch11', 'Batch12', 'Batch13', 'Batch14', 'Batch15', 'Batch16', 'Batch17', 'Batch18', 'Batch19', 'Batch20', 'Batch21', 'Batch22', 'Batch23', 'Batch25', 'Batch26', 'Batch24', 'Batch27', 'Batch28', 'Batch29', 'Batch30', 'Batch31', 'Batch32', 'Batch33', 'Batch35', 'Batch37', 'Batch34', 'Batch36', 'Batch38', 'Batch39', 'Batch40', 'Batch41', 'Batch43', 'Batch42', 'Batch44', 'Batch45', 'Batch46', 'Batch50', 'Batch49', 'Batch48', 'Batch47', 'Batch51', 'Batch52', 'Batch53', '
', 'Batch45Dup1.npy', 'Batch46Dup1.npy', 'Batch50Dup1.npy', 'Batch49Dup1.npy', 'Batch48Dup1.npy', 'Batch47Dup1.npy', 'Batch51Dup1.npy', 'Batch52Dup1.npy', 'Batch53Dup1.npy', 'Batch54Dup1.npy', 'Batch55Dup1.npy', 'Batch56Dup1.npy', 'Batch57Dup1.npy', 'Batch58Dup1.npy', 'Batch59Dup1.npy', 'Batch60Dup1.npy', 'Batch61Dup1.npy', 'Batch66Dup1.npy', 'Batch65Dup1.npy', 'Batch64Dup1.npy', 'Batch63Dup1.npy', 'Batch62Dup1.npy', 'Batch67Dup1.npy', 'Batch68Dup1.npy', 'Batch69Dup1.npy', 'Batch70Dup1.npy', 'Batch73Dup1.npy', 'Batch71Dup1.npy', 'Batch72Dup1.npy', 'Batch74Dup1.npy', 'Batch75Dup1.npy', 'Batch77Dup1.npy', 'Batch78Dup1.npy ...
# Batch1 Dup2 skipped (32, 60, 2560)
# Batch2 Dup2 skipped (32, 60, 2560)
# Batch3 Dup2 skipped (32, 60, 2560)
# Batch4 Dup2 skipped (32, 60, 2560)
# Batch5 Dup2 skipped (32, 60, 2560)
# Batch6 Dup2 skipped (32, 60, 2560)
# Batch7 Dup2 skipped (32, 60, 2560)
# Batch8 Dup2 skipped (32, 60, 2560)
# Batch9 Dup2 skipped (32, 60, 2560)
# Batch10 Dup2 skipped (32, 60, 2560)
# Batch11 Dup2 skipped (32, 60, 2560)
# Batch12 Dup2 skipped (32, 60, 2560)
# Batch13 Dup2 skipped (32, 60, 2560)
# Batch14 Dup2 skipped (32, 60, 2560)
# Batch15 Dup2 skipped (32, 60, 2560)
# Batch16 Dup2 skipped (32, 60, 2560)
# Batch17 Dup2 skipped (32, 60, 2560)
# Batch18 Dup2 skipped (32, 60, 2560)
# Batch19 Dup2 skipped (32, 60, 2560)
# Batch20 Dup2 skipped (32, 60, 2560)
# Batch21 Dup2 skipped (32, 60, 2560)
# Batch22 Dup2 skipped (32, 60, 2560)
# Batch23 Dup2 skipped (32, 60, 2560)
# Batch25 Dup2 skipped (32, 60, 2560)
# Batch26 Dup2 skipped (32, 60, 2560)
# Batch24 Dup2 skipped (32, 60, 2560)
# Batch27 Dup2 skipped (32, 60, 2560)
# Batch28 Dup2 skipped (32, 60, 2560)
# Batch29 Dup2 skipped (32, 60, 2560)
# Batch30 Dup2 skipped (32, 60, 2560)
# Batch31 Dup2 skipped (32, 60, 2560)
# Batch32 Dup2 skipped (32, 60, 2560)
# Batch33 Dup2 skipped (32, 60, 2560)
# Batch35 Dup2 skipped (32, 60, 2560)
# Batch37 Dup2 skipped (32, 60, 2560)
# Batch34 Dup2 skipped (32, 60, 2560)
# Batch36 Dup2 skipped (32, 60, 2560)
# Batch38 Dup2 skipped (32, 60, 2560)
# Batch39 Dup2 skipped (32, 60, 2560)
# Batch40 Dup2 skipped (32, 60, 2560)
# Batch41 Dup2 skipped (32, 60, 2560)
# Batch43 Dup2 skipped (32, 60, 2560)
# Batch42 Dup2 skipped (32, 60, 2560)
# Batch44 Dup2 skipped (32, 60, 2560)
# Batch45 Dup2 skipped (32, 60, 2560)
# Batch46 Dup2 skipped (32, 60, 2560)
# Batch50 Dup2 skipped (32, 60, 2560)
# Batch49 Dup2 skipped (32, 60, 2560)
# Batch48 Dup2 skipped (32, 60, 2560)
# Batch47 Dup2 skipped (32, 60, 2560)
# Batch51 Dup2 skipped (32, 60, 2560)
# Batch52 Dup2 skipped (32, 60, 2560)
# Batch53 Dup2 skipped (32, 60, 2560)
# Batch54 Dup2 skipped (32, 60, 2560)
# Batch55 Dup2 skipped (32, 60, 2560)
# Batch56 Dup2 skipped (32, 60, 2560)
# Batch57 Dup2 skipped (32, 60, 2560)
# Batch58 Dup2 skipped (32, 60, 2560)
# Batch59 Dup2 skipped (32, 60, 2560)
# Batch60 Dup2 skipped (32, 60, 2560)
# Batch61 Dup2 skipped (32, 60, 2560)
# Batch66 Dup2 skipped (32, 60, 2560)
# Batch65 Dup2 skipped (32, 60, 2560)
# Batch64 Dup2 skipped (32, 60, 2560)
# Batch63 Dup2 skipped (32, 60, 2560)
# Batch62 Dup2 skipped (32, 60, 2560)
# Batch67 Dup2 skipped (32, 60, 2560)
# Batch68 Dup2 skipped (32, 60, 2560)
# Batch69 Dup2 skipped (32, 60, 2560)
# Batch70 Dup2 skipped (32, 60, 2560)
# Batch73 Dup2 skipped (32, 60, 2560)
# Batch71 Dup2 skipped (32, 60, 2560)
# Batch72 Dup2 skipped (32, 60, 2560)
# Batch74 Dup2 skipped (32, 60, 2560)
# Batch75 Dup2 skipped (32, 60, 2560)
# Batch77 Dup2 skipped (32, 60, 2560)
# Batch78 Dup2 skipped (32, 60, 2560)
# Batch79 Dup2 skipped (32, 60, 2560)
# Batch80 Dup2 skipped (32, 60, 2560)
# Batch76 Dup2 skipped (32, 60, 2560)
# Batch81 Dup2 skipped (32, 60, 2560)
# Batch82 Dup2 skipped (32, 60, 2560)
# Batch83 Dup2 skipped (32, 60, 2560)
# Batch84 Dup2 skipped (32, 60, 2560)
# Batch85 Dup2 skipped (32, 60, 2560)
# Batch86 Dup2 skipped (32, 60, 2560)
# Batch87 Dup2 skipped (32, 60, 2560)
# Batch88 Dup2 skipped (32, 60, 2560)
# Batch89 Dup2 skipped (32, 60, 2560)
# Batch90 Dup2 skipped (32, 60, 2560)
# Batch91 Dup2 skipped (32, 60, 2560)
# Batch92 Dup2 skipped (32, 60, 2560)
# Batch95 Dup2 skipped (32, 60, 2560)
# Batch93 Dup2 skipped (32, 60, 2560)
# Batch94 Dup2 skipped (32, 60, 2560)
# Batch96 Dup2 skipped (32, 60, 2560)
# Batch100 Dup2 skipped (32, 60, 2560)
# Batch99 Dup2 skipped (32, 60, 2560)
# Batch98 Dup2 skipped (32, 60, 2560)
# Batch97 Dup2 skipped (32, 60, 2560)
# Batch101 Dup2 skipped (32, 60, 2560)
# Batch102 Dup2 skipped (32, 60, 2560)
# Batch103 Dup2 skipped (32, 60, 2560)
# Batch104 Dup2 skipped (32, 60, 2560)
# Batch105 Dup2 skipped (32, 60, 2560)
# Batch106 Dup2 skipped (32, 60, 2560)
# Batch107 Dup2 skipped (32, 60, 2560)
# Batch108 Dup2 skipped (32, 60, 2560)
# Batch109 Dup2 skipped (32, 60, 2560)
# Batch110 Dup2 skipped (32, 60, 2560)
# Batch111 Dup2 skipped (32, 60, 2560)
# Batch112 Dup2 skipped (32, 60, 2560)
# Batch113 Dup2 skipped (32, 60, 2560)
# Batch114 Dup2 skipped (32, 60, 2560)
# Batch115 Dup2 skipped (32, 60, 2560)
# Batch116 Dup2 skipped (32, 60, 2560)
# Batch117 Dup2 skipped (32, 60, 2560)
# Batch118 Dup2 skipped (32, 60, 2560)
# Batch119 Dup2 skipped (32, 60, 2560)
# Batch120 Dup2 skipped (32, 60, 2560)
# Batch121 Dup2 skipped (32, 60, 2560)
# Batch122 Dup2 skipped (32, 60, 2560)
# Batch123 Dup2 skipped (32, 60, 2560)
# Batch125 Dup2 skipped (32, 60, 2560)
# Batch124 Dup2 skipped (32, 60, 2560)
# Batch126 Dup2 skipped (32, 60, 2560)
# Batch127 Dup2 skipped (32, 60, 2560)
# Batch128 Dup2 skipped (32, 60, 2560)
# Batch129 Dup2 skipped (32, 60, 2560)
# Batch130 Dup2 skipped (32, 60, 2560)
# Batch131 Dup2 skipped (32, 60, 2560)
# Batch132 Dup2 skipped (32, 60, 2560)
# Batch133 Dup2 skipped (32, 60, 2560)
# Batch134 Dup2 skipped (32, 60, 2560)
# Batch135 Dup2 skipped (32, 60, 2560)
# Batch136 Dup2 skipped (32, 60, 2560)
# Batch137 Dup2 skipped (32, 60, 2560)
# Batch140 Dup2 skipped (32, 60, 2560)
# Batch139 Dup2 skipped (32, 60, 2560)
# Batch138 Dup2 skipped (32, 60, 2560)
# Batch141 Dup2 skipped (32, 60, 2560)
# Batch142 Dup2 skipped (32, 60, 2560)
# Batch143 Dup2 skipped (32, 60, 2560)
# Batch144 Dup2 skipped (32, 60, 2560)
# Batch145 Dup2 skipped (32, 60, 2560)
# Batch146 Dup2 skipped (32, 60, 2560)
# Batch166 Dup2 skipped (32, 60, 2560)
# Batch163 Dup2 skipped (32, 60, 2560)
# Batch165 Dup2 skipped (32, 60, 2560)
# Batch150 Dup2 skipped (32, 60, 2560)
# Batch156 Dup2 skipped (32, 60, 2560)
# Batch164 Dup2 skipped (32, 60, 2560)
# Batch158 Dup2 skipped (32, 60, 2560)
# Batch157 Dup2 skipped (32, 60, 2560)
# Batch152 Dup2 skipped (32, 60, 2560)
# Batch162 Dup2 skipped (32, 60, 2560)
# Batch161 Dup2 skipped (32, 60, 2560)
# Batch147 Dup2 skipped (32, 60, 2560)
# Batch148 Dup2 skipped (32, 60, 2560)
# Batch149 Dup2 skipped (32, 60, 2560)
# Batch151 Dup2 skipped (32, 60, 2560)
# Batch153 Dup2 skipped (32, 60, 2560)
# Batch154 Dup2 skipped (32, 60, 2560)
# Batch155 Dup2 skipped (32, 60, 2560)
# Batch159 Dup2 skipped (32, 60, 2560)
# Batch160 Dup2 skipped (32, 60, 2560)

# %%
currentPart = part4
batches_list = os.listdir(train_video_path)
print(batches_list)
saved_batches = os.listdir(saved_nparray_path) #no need for this if we have good reources
print(saved_batches)
counter = 0
for batch in batches_list:
        if batch+"Dup3.npy" in saved_batches: #no need for the if we have no resources
          skippedBatch = np.load(os.path.join(train_nparray_path, "data" , batch+".npy"))
          print(batch, "Dup3 skipped", skippedBatch.shape)
          continue
        print(batch)
        x_batch, y_batch = create_Data(os.path.join(train_video_path, batch))
        x_batch = np.asarray(x_batch)
        y_batch = np.asarray(y_batch)
        np.save(os.path.join(train_nparray_path, "data", batch+"Dup3"), x_batch)
        np.save(os.path.join(train_nparray_path, "label", batch+"Dup3"), y_batch)

        counter += 1
        print(counter)
# Out:
# ['Batch1', 'Batch2', 'Batch3', 'Batch4', 'Batch5', 'Batch6', 'Batch7', 'Batch8', 'Batch9', 'Batch10', 'Batch11', 'Batch12', 'Batch13', 'Batch14', 'Batch15', 'Batch16', 'Batch17', 'Batch18', 'Batch19', 'Batch20', 'Batch21', 'Batch22', 'Batch23', 'Batch25', 'Batch26', 'Batch24', 'Batch27', 'Batch28', 'Batch29', 'Batch30', 'Batch31', 'Batch32', 'Batch33', 'Batch35', 'Batch37', 'Batch34', 'Batch36', 'Batch38', 'Batch39', 'Batch40', 'Batch41', 'Batch43', 'Batch42', 'Batch44', 'Batch45', 'Batch46', 'Batch50', 'Batch49', 'Batch48', 'Batch47', 'Batch51', 'Batch52', 'Batch53', 'Batch54', 'Batch55', 'Batch56', 'Batch57', 'Batch58', 'Batch59', 'Batch60', 'Batch61', 'Batch66', 'Batch65', 'Batch64', 'Batch63', 'Batch62', 'Batch67', 'Batch68', 'Batch69', 'Batch70', 'Batch73', 'Batch71', 'Batch72', 'Batch74', 'Batch75', 'Batch77', 'Batch78', 'Batch79', 'Batch80', 'Batch76', 'Batch81', 'Batch82', 'Batch83', 'Batch84', 'Batch85', 'Batch86', 'Batch87', 'Batch88', 'Batch89', 'Batch90', 'Batch91', 'Batch92', 'Batch95', 'Batch93', 'Batch94', 'Batch96', 'Batch100', 'Batch99', 'Batch98', 'Batch97', 'Batch101', 'Batch102', 'Batch103', 'Batch104', 'Batch105', 'Batch106', 'Batch107', 'Batch108', 'Batch109', 'Batch110', 'Batch111', 'Batch112', 'Batch113', 'Batch114', 'Batch115', 'Batch116', 'Batch117', 'Batch118', 'Batch119', 'Batch120', 'Batch121', 'Batch122', 'Batch123', 'Batch125', 'Batch124', 'Batch126', 'Batch127', 'Batch128', 'Batch129', 'Batch130', 'Batch131', 'Batch132', 'Batch133', 'Batch134', 'Batch135', 'Batch136', 'Batch137', 'Batch140', 'Batch139', 'Batch138', 'Batch141', 'Batch142', 'Batch143', 'Batch144', 'Batch145', 'Batch146', 'Batch166', 'Batch163', 'Batch165', 'Batch150', 'Batch156', 'Batch164', 'Batch158', 'Batch157', 'Batch152', 'Batch162', 'Batch161', 'Batch147', 'Batch148', 'Batch149', 'Batch151', 'Batch153', 'Batch154', 'Batch155', 'Batch159', 'Batch160']
.npy', 'Batch158.npy', 'Batch157.npy', 'Batch152.npy', 'Batch162.npy', 'Batch161.npy', 'Batch147.npy', 'Batch148.npy', 'Batch149.npy', 'Batch151.npy', 'Batch153.npy', 'Batch154.npy', 'Batch155.npy', 'Batch159.npy', 'Batch160.npy', 'Batch1Dup1.npy', 'Batch2Dup1.npy', 'Batch3Dup1.npy', 'Batch4Dup1.npy', 'Batch5Dup1.npy', 'Batch6Dup1.npy', 'Batch7Dup1.npy', 'Batch8Dup1.npy', 'Batch9Dup1.npy', 'Batch10Dup1.npy', 'Batch11Dup1.npy', 'Batch12Dup1.npy', 'Batch13Dup1.npy', 'Batch14Dup1.npy', 'Batch15Dup1.npy', 'Batch16Dup1.npy', 'Batch17Dup1.npy', 'Batch18Dup1.npy', 'Batch19Dup1.npy', 'Batch20Dup1.npy', 'Batch21Dup1.npy', 'Batch22Dup1.npy', 'Batch23Dup1.npy', 'Batch25Dup1.npy', 'Batch26Dup1.npy', 'Batch24Dup1.npy', 'Batch27Dup1.npy', 'Batch28Dup1.npy', 'Batch29Dup1.npy', 'Batch30Dup1.npy', 'Batch31Dup1.npy', 'Batch32Dup1.npy', 'Batch33Dup1.npy', 'Batch35Dup1.npy', 'Batch37Dup1.npy', 'Batch34Dup1.npy', 'Batch36Dup1.npy', 'Batch38Dup1.npy', 'Batch39Dup1.npy', 'Batch40Dup1.npy', 'Batch41Dup1.npy', 'Batch43Dup1.npy', 'Batch42Dup1.npy', 'Batch44Dup1.npy', 'Batch45Dup1.npy', 'Batch46Dup1.npy', 'Batch50Dup1.npy', 'Batch49Dup1.npy', 'Batch48Dup1.npy', 'Batch47Dup1.npy', 'Batch51Dup1.npy', 'Batch52Dup1.npy', 'Batch53Dup1.npy', 'Batch54Dup1.npy', 'Batch55Dup1.npy', 'Batch56Dup1.npy', 'Batch57Dup1.npy', 'Batch58Dup1.npy', 'Batch59Dup1.npy', 'Batch60Dup1.npy', 'Batch61Dup1.npy', 'Batch66Dup1.npy', 'Batch65Dup1.npy', 'Batch64Dup1.npy', 'Batch63Dup1.npy', 'Batch62Dup1.npy', 'Batch67Dup1.npy', 'Batch68Dup1.npy', 'Batch69Dup1.npy', 'Batch70Dup1.npy', 'Batch73Dup1.npy', 'Batch71Dup1.npy', 'Batch72Dup1.npy', 'Batch74Dup1.npy', 'Batch75Dup1.npy', 'Batch77Dup1.npy', 'Batch78Dup1.npy ...
# Batch1 Dup3 skipped (32, 60, 2560)
# Batch2 Dup3 skipped (32, 60, 2560)
# Batch3 Dup3 skipped (32, 60, 2560)
# Batch4 Dup3 skipped (32, 60, 2560)
# Batch5 Dup3 skipped (32, 60, 2560)
# Batch6 Dup3 skipped (32, 60, 2560)
# Batch7 Dup3 skipped (32, 60, 2560)
# Batch8 Dup3 skipped (32, 60, 2560)
# Batch9 Dup3 skipped (32, 60, 2560)
# Batch10 Dup3 skipped (32, 60, 2560)
# Batch11 Dup3 skipped (32, 60, 2560)
# Batch12 Dup3 skipped (32, 60, 2560)
# Batch13 Dup3 skipped (32, 60, 2560)
# Batch14 Dup3 skipped (32, 60, 2560)
# Batch15 Dup3 skipped (32, 60, 2560)
# Batch16 Dup3 skipped (32, 60, 2560)
# Batch17 Dup3 skipped (32, 60, 2560)
# Batch18 Dup3 skipped (32, 60, 2560)
# Batch19 Dup3 skipped (32, 60, 2560)
# Batch20 Dup3 skipped (32, 60, 2560)
# Batch21 Dup3 skipped (32, 60, 2560)
# Batch22 Dup3 skipped (32, 60, 2560)
# Batch23 Dup3 skipped (32, 60, 2560)
# Batch25 Dup3 skipped (32, 60, 2560)
# Batch26 Dup3 skipped (32, 60, 2560)
# Batch24 Dup3 skipped (32, 60, 2560)
# Batch27 Dup3 skipped (32, 60, 2560)
# Batch28 Dup3 skipped (32, 60, 2560)
# Batch29 Dup3 skipped (32, 60, 2560)
# Batch30 Dup3 skipped (32, 60, 2560)
# Batch31 Dup3 skipped (32, 60, 2560)
# Batch32 Dup3 skipped (32, 60, 2560)
# Batch33 Dup3 skipped (32, 60, 2560)
# Batch35 Dup3 skipped (32, 60, 2560)
# Batch37 Dup3 skipped (32, 60, 2560)
# Batch34 Dup3 skipped (32, 60, 2560)
# Batch36 Dup3 skipped (32, 60, 2560)
# Batch38 Dup3 skipped (32, 60, 2560)
# Batch39 Dup3 skipped (32, 60, 2560)
# Batch40 Dup3 skipped (32, 60, 2560)
# Batch41 Dup3 skipped (32, 60, 2560)
# Batch43 Dup3 skipped (32, 60, 2560)
# Batch42 Dup3 skipped (32, 60, 2560)
# Batch44 Dup3 skipped (32, 60, 2560)
# Batch45 Dup3 skipped (32, 60, 2560)
# Batch46 Dup3 skipped (32, 60, 2560)
# Batch50 Dup3 skipped (32, 60, 2560)
# Batch49 Dup3 skipped (32, 60, 2560)
# Batch48 Dup3 skipped (32, 60, 2560)
# Batch47 Dup3 skipped (32, 60, 2560)
# Batch51 Dup3 skipped (32, 60, 2560)
# Batch52 Dup3 skipped (32, 60, 2560)
# Batch53 Dup3 skipped (32, 60, 2560)
# Batch54 Dup3 skipped (32, 60, 2560)
# Batch55 Dup3 skipped (32, 60, 2560)
# Batch56 Dup3 skipped (32, 60, 2560)
# Batch57 Dup3 skipped (32, 60, 2560)
# Batch58 Dup3 skipped (32, 60, 2560)
# Batch59 Dup3 skipped (32, 60, 2560)
# Batch60 Dup3 skipped (32, 60, 2560)
# Batch61 Dup3 skipped (32, 60, 2560)
# Batch66 Dup3 skipped (32, 60, 2560)
# Batch65 Dup3 skipped (32, 60, 2560)
# Batch64 Dup3 skipped (32, 60, 2560)
# Batch63 Dup3 skipped (32, 60, 2560)
# Batch62 Dup3 skipped (32, 60, 2560)
# Batch67 Dup3 skipped (32, 60, 2560)
# Batch68 Dup3 skipped (32, 60, 2560)
# Batch69 Dup3 skipped (32, 60, 2560)
# Batch70 Dup3 skipped (32, 60, 2560)
# Batch73 Dup3 skipped (32, 60, 2560)
# Batch71 Dup3 skipped (32, 60, 2560)
# Batch72 Dup3 skipped (32, 60, 2560)
# Batch74 Dup3 skipped (32, 60, 2560)
# Batch75 Dup3 skipped (32, 60, 2560)
# Batch77 Dup3 skipped (32, 60, 2560)
# Batch78 Dup3 skipped (32, 60, 2560)
# Batch79 Dup3 skipped (32, 60, 2560)
# Batch80 Dup3 skipped (32, 60, 2560)
# Batch76 Dup3 skipped (32, 60, 2560)
# Batch81 Dup3 skipped (32, 60, 2560)
# Batch82 Dup3 skipped (32, 60, 2560)
# Batch83 Dup3 skipped (32, 60, 2560)
# Batch84 Dup3 skipped (32, 60, 2560)
# Batch85 Dup3 skipped (32, 60, 2560)
# Batch86 Dup3 skipped (32, 60, 2560)
# Batch87 Dup3 skipped (32, 60, 2560)
# Batch88 Dup3 skipped (32, 60, 2560)
# Batch89 Dup3 skipped (32, 60, 2560)
# Batch90 Dup3 skipped (32, 60, 2560)
# Batch91 Dup3 skipped (32, 60, 2560)
# Batch92 Dup3 skipped (32, 60, 2560)
# Batch95 Dup3 skipped (32, 60, 2560)
# Batch93 Dup3 skipped (32, 60, 2560)
# Batch94 Dup3 skipped (32, 60, 2560)
# Batch96 Dup3 skipped (32, 60, 2560)
# Batch100 Dup3 skipped (32, 60, 2560)
# Batch99 Dup3 skipped (32, 60, 2560)
# Batch98 Dup3 skipped (32, 60, 2560)
# Batch97 Dup3 skipped (32, 60, 2560)
# Batch101 Dup3 skipped (32, 60, 2560)
# Batch102 Dup3 skipped (32, 60, 2560)
# Batch103 Dup3 skipped (32, 60, 2560)
# Batch104 Dup3 skipped (32, 60, 2560)
# Batch105 Dup3 skipped (32, 60, 2560)
# Batch106 Dup3 skipped (32, 60, 2560)
# Batch107 Dup3 skipped (32, 60, 2560)
# Batch108 Dup3 skipped (32, 60, 2560)
# Batch109 Dup3 skipped (32, 60, 2560)
# Batch110 Dup3 skipped (32, 60, 2560)
# Batch111 Dup3 skipped (32, 60, 2560)
# Batch112 Dup3 skipped (32, 60, 2560)
# Batch113 Dup3 skipped (32, 60, 2560)
# Batch114 Dup3 skipped (32, 60, 2560)
# Batch115 Dup3 skipped (32, 60, 2560)
# Batch116 Dup3 skipped (32, 60, 2560)
# Batch117 Dup3 skipped (32, 60, 2560)
# Batch118 Dup3 skipped (32, 60, 2560)
# Batch119 Dup3 skipped (32, 60, 2560)
# Batch120 Dup3 skipped (32, 60, 2560)
# Batch121 Dup3 skipped (32, 60, 2560)
# Batch122 Dup3 skipped (32, 60, 2560)
# Batch123 Dup3 skipped (32, 60, 2560)
# Batch125 Dup3 skipped (32, 60, 2560)
# Batch124 Dup3 skipped (32, 60, 2560)
# Batch126 Dup3 skipped (32, 60, 2560)
# Batch127 Dup3 skipped (32, 60, 2560)
# Batch128 Dup3 skipped (32, 60, 2560)
# Batch129 Dup3 skipped (32, 60, 2560)
# Batch130 Dup3 skipped (32, 60, 2560)
# Batch131 Dup3 skipped (32, 60, 2560)
# Batch132 Dup3 skipped (32, 60, 2560)
# Batch133 Dup3 skipped (32, 60, 2560)
# Batch134 Dup3 skipped (32, 60, 2560)
# Batch135 Dup3 skipped (32, 60, 2560)
# Batch136 Dup3 skipped (32, 60, 2560)
# Batch137 Dup3 skipped (32, 60, 2560)
# Batch140 Dup3 skipped (32, 60, 2560)
# Batch139 Dup3 skipped (32, 60, 2560)
# Batch138 Dup3 skipped (32, 60, 2560)
# Batch141 Dup3 skipped (32, 60, 2560)
# Batch142 Dup3 skipped (32, 60, 2560)
# Batch143 Dup3 skipped (32, 60, 2560)
# Batch144 Dup3 skipped (32, 60, 2560)
# Batch145 Dup3 skipped (32, 60, 2560)
# Batch146 Dup3 skipped (32, 60, 2560)
# Batch166 Dup3 skipped (32, 60, 2560)
# Batch163 Dup3 skipped (32, 60, 2560)
# Batch165 Dup3 skipped (32, 60, 2560)
# Batch150 Dup3 skipped (32, 60, 2560)
# Batch156 Dup3 skipped (32, 60, 2560)
# Batch164 Dup3 skipped (32, 60, 2560)
# Batch158 Dup3 skipped (32, 60, 2560)
# Batch157 Dup3 skipped (32, 60, 2560)
# Batch152 Dup3 skipped (32, 60, 2560)
# Batch162 Dup3 skipped (32, 60, 2560)
# Batch161 Dup3 skipped (32, 60, 2560)
# Batch147 Dup3 skipped (32, 60, 2560)
# Batch148 Dup3 skipped (32, 60, 2560)
# Batch149 Dup3 skipped (32, 60, 2560)
# Batch151 Dup3 skipped (32, 60, 2560)
# Batch153 Dup3 skipped (32, 60, 2560)
# Batch154 Dup3 skipped (32, 60, 2560)
# Batch155 Dup3 skipped (32, 60, 2560)
# Batch159 Dup3 skipped (32, 60, 2560)
# Batch160 Dup3 skipped (32, 60, 2560)

# %%
currentPart = part5
batches_list = os.listdir(train_video_path)
print(batches_list)
saved_batches = os.listdir(saved_nparray_path) #no need for this if we have good reources
print(saved_batches)
counter = 0
for batch in batches_list:
        if batch+"Dup4.npy" in saved_batches: #no need for the if we have no resources
          skippedBatch = np.load(os.path.join(train_nparray_path, "data" , batch+".npy"))
          print(batch, "Dup4 skipped", skippedBatch.shape)
          continue
        print(batch)
        x_batch, y_batch = create_Data(os.path.join(train_video_path, batch))
        x_batch = np.asarray(x_batch)
        y_batch = np.asarray(y_batch)
        np.save(os.path.join(train_nparray_path, "data", batch+"Dup4"), x_batch)
        np.save(os.path.join(train_nparray_path, "label", batch+"Dup4"), y_batch)

        counter += 1
        print(counter)
# Out:
# ['Batch1', 'Batch2', 'Batch3', 'Batch4', 'Batch5', 'Batch6', 'Batch7', 'Batch8', 'Batch9', 'Batch10', 'Batch11', 'Batch12', 'Batch13', 'Batch14', 'Batch15', 'Batch16', 'Batch17', 'Batch18', 'Batch19', 'Batch20', 'Batch21', 'Batch22', 'Batch23', 'Batch25', 'Batch26', 'Batch24', 'Batch27', 'Batch28', 'Batch29', 'Batch30', 'Batch31', 'Batch32', 'Batch33', 'Batch35', 'Batch37', 'Batch34', 'Batch36', 'Batch38', 'Batch39', 'Batch40', 'Batch41', 'Batch43', 'Batch42', 'Batch44', 'Batch45', 'Batch46', 'Batch50', 'Batch49', 'Batch48', 'Batch47', 'Batch51', 'Batch52', 'Batch53', 'Batch54', 'Batch55', '
 'Batch46Dup1.npy', 'Batch50Dup1.npy', 'Batch49Dup1.npy', 'Batch48Dup1.npy', 'Batch47Dup1.npy', 'Batch51Dup1.npy', 'Batch52Dup1.npy', 'Batch53Dup1.npy', 'Batch54Dup1.npy', 'Batch55Dup1.npy', 'Batch56Dup1.npy', 'Batch57Dup1.npy', 'Batch58Dup1.npy', 'Batch59Dup1.npy', 'Batch60Dup1.npy', 'Batch61Dup1.npy', 'Batch66Dup1.npy', 'Batch65Dup1.npy', 'Batch64Dup1.npy', 'Batch63Dup1.npy', 'Batch62Dup1.npy', 'Batch67Dup1.npy', 'Batch68Dup1.npy', 'Batch69Dup1.npy', 'Batch70Dup1.npy', 'Batch73Dup1.npy', 'Batch71Dup1.npy', 'Batch72Dup1.npy', 'Batch74Dup1.npy', 'Batch75Dup1.npy', 'Batch77Dup1.npy', 'Batch78Dup1.npy ...
# Batch1 Dup4 skipped (32, 60, 2560)
# Batch2 Dup4 skipped (32, 60, 2560)
# Batch3 Dup4 skipped (32, 60, 2560)
# Batch4 Dup4 skipped (32, 60, 2560)
# Batch5 Dup4 skipped (32, 60, 2560)
# Batch6 Dup4 skipped (32, 60, 2560)
# Batch7 Dup4 skipped (32, 60, 2560)
# Batch8 Dup4 skipped (32, 60, 2560)
# Batch9 Dup4 skipped (32, 60, 2560)
# Batch10 Dup4 skipped (32, 60, 2560)
# Batch11 Dup4 skipped (32, 60, 2560)
# Batch12 Dup4 skipped (32, 60, 2560)
# Batch13 Dup4 skipped (32, 60, 2560)
# Batch14 Dup4 skipped (32, 60, 2560)
# Batch15 Dup4 skipped (32, 60, 2560)
# Batch16 Dup4 skipped (32, 60, 2560)
# Batch17 Dup4 skipped (32, 60, 2560)
# Batch18 Dup4 skipped (32, 60, 2560)
# Batch19 Dup4 skipped (32, 60, 2560)
# Batch20 Dup4 skipped (32, 60, 2560)
# Batch21 Dup4 skipped (32, 60, 2560)
# Batch22 Dup4 skipped (32, 60, 2560)
# Batch23 Dup4 skipped (32, 60, 2560)
# Batch25 Dup4 skipped (32, 60, 2560)
# Batch26 Dup4 skipped (32, 60, 2560)
# Batch24 Dup4 skipped (32, 60, 2560)
# Batch27 Dup4 skipped (32, 60, 2560)
# Batch28 Dup4 skipped (32, 60, 2560)
# Batch29 Dup4 skipped (32, 60, 2560)
# Batch30 Dup4 skipped (32, 60, 2560)
# Batch31 Dup4 skipped (32, 60, 2560)
# Batch32 Dup4 skipped (32, 60, 2560)
# Batch33 Dup4 skipped (32, 60, 2560)
# Batch35 Dup4 skipped (32, 60, 2560)
# Batch37 Dup4 skipped (32, 60, 2560)
# Batch34 Dup4 skipped (32, 60, 2560)
# Batch36 Dup4 skipped (32, 60, 2560)
# Batch38 Dup4 skipped (32, 60, 2560)
# Batch39 Dup4 skipped (32, 60, 2560)
# Batch40 Dup4 skipped (32, 60, 2560)
# Batch41 Dup4 skipped (32, 60, 2560)
# Batch43 Dup4 skipped (32, 60, 2560)
# Batch42 Dup4 skipped (32, 60, 2560)
# Batch44 Dup4 skipped (32, 60, 2560)
# Batch45 Dup4 skipped (32, 60, 2560)
# Batch46 Dup4 skipped (32, 60, 2560)
# Batch50 Dup4 skipped (32, 60, 2560)
# Batch49 Dup4 skipped (32, 60, 2560)
# Batch48 Dup4 skipped (32, 60, 2560)
# Batch47 Dup4 skipped (32, 60, 2560)
# Batch51 Dup4 skipped (32, 60, 2560)
# Batch52 Dup4 skipped (32, 60, 2560)
# Batch53 Dup4 skipped (32, 60, 2560)
# Batch54 Dup4 skipped (32, 60, 2560)
# Batch55 Dup4 skipped (32, 60, 2560)
# Batch56 Dup4 skipped (32, 60, 2560)
# Batch57 Dup4 skipped (32, 60, 2560)
# Batch58 Dup4 skipped (32, 60, 2560)
# Batch59 Dup4 skipped (32, 60, 2560)
# Batch60 Dup4 skipped (32, 60, 2560)
# Batch61 Dup4 skipped (32, 60, 2560)
# Batch66 Dup4 skipped (32, 60, 2560)
# Batch65 Dup4 skipped (32, 60, 2560)
# Batch64 Dup4 skipped (32, 60, 2560)
# Batch63 Dup4 skipped (32, 60, 2560)
# Batch62 Dup4 skipped (32, 60, 2560)
# Batch67 Dup4 skipped (32, 60, 2560)
# Batch68 Dup4 skipped (32, 60, 2560)
# Batch69 Dup4 skipped (32, 60, 2560)
# Batch70 Dup4 skipped (32, 60, 2560)
# Batch73 Dup4 skipped (32, 60, 2560)
# Batch71 Dup4 skipped (32, 60, 2560)
# Batch72 Dup4 skipped (32, 60, 2560)
# Batch74 Dup4 skipped (32, 60, 2560)
# Batch75 Dup4 skipped (32, 60, 2560)
# Batch77 Dup4 skipped (32, 60, 2560)
# Batch78 Dup4 skipped (32, 60, 2560)
# Batch79 Dup4 skipped (32, 60, 2560)
# Batch80 Dup4 skipped (32, 60, 2560)
# Batch76 Dup4 skipped (32, 60, 2560)
# Batch81 Dup4 skipped (32, 60, 2560)
# Batch82 Dup4 skipped (32, 60, 2560)
# Batch83 Dup4 skipped (32, 60, 2560)
# Batch84 Dup4 skipped (32, 60, 2560)
# Batch85 Dup4 skipped (32, 60, 2560)
# Batch86 Dup4 skipped (32, 60, 2560)
# Batch87 Dup4 skipped (32, 60, 2560)
# Batch88 Dup4 skipped (32, 60, 2560)
# Batch89 Dup4 skipped (32, 60, 2560)
# Batch90 Dup4 skipped (32, 60, 2560)
# Batch91 Dup4 skipped (32, 60, 2560)
# Batch92 Dup4 skipped (32, 60, 2560)
# Batch95 Dup4 skipped (32, 60, 2560)
# Batch93 Dup4 skipped (32, 60, 2560)
# Batch94 Dup4 skipped (32, 60, 2560)
# Batch96 Dup4 skipped (32, 60, 2560)
# Batch100 Dup4 skipped (32, 60, 2560)
# Batch99 Dup4 skipped (32, 60, 2560)
# Batch98 Dup4 skipped (32, 60, 2560)
# Batch97 Dup4 skipped (32, 60, 2560)
# Batch101 Dup4 skipped (32, 60, 2560)
# Batch102 Dup4 skipped (32, 60, 2560)
# Batch103 Dup4 skipped (32, 60, 2560)
# Batch104 Dup4 skipped (32, 60, 2560)
# Batch105 Dup4 skipped (32, 60, 2560)
# Batch106 Dup4 skipped (32, 60, 2560)
# Batch107 Dup4 skipped (32, 60, 2560)
# Batch108 Dup4 skipped (32, 60, 2560)
# Batch109 Dup4 skipped (32, 60, 2560)
# Batch110 Dup4 skipped (32, 60, 2560)
# Batch111 Dup4 skipped (32, 60, 2560)
# Batch112 Dup4 skipped (32, 60, 2560)
# Batch113 Dup4 skipped (32, 60, 2560)
# Batch114 Dup4 skipped (32, 60, 2560)
# Batch115 Dup4 skipped (32, 60, 2560)
# Batch116 Dup4 skipped (32, 60, 2560)
# Batch117 Dup4 skipped (32, 60, 2560)
# Batch118 Dup4 skipped (32, 60, 2560)
# Batch119 Dup4 skipped (32, 60, 2560)
# Batch120 Dup4 skipped (32, 60, 2560)
# Batch121 Dup4 skipped (32, 60, 2560)
# Batch122 Dup4 skipped (32, 60, 2560)
# Batch123 Dup4 skipped (32, 60, 2560)
# Batch125 Dup4 skipped (32, 60, 2560)
# Batch124 Dup4 skipped (32, 60, 2560)
# Batch126 Dup4 skipped (32, 60, 2560)
# Batch127 Dup4 skipped (32, 60, 2560)
# Batch128 Dup4 skipped (32, 60, 2560)
# Batch129 Dup4 skipped (32, 60, 2560)
# Batch130 Dup4 skipped (32, 60, 2560)
# Batch131 Dup4 skipped (32, 60, 2560)
# Batch132 Dup4 skipped (32, 60, 2560)
# Batch133 Dup4 skipped (32, 60, 2560)
# Batch134 Dup4 skipped (32, 60, 2560)
# Batch135 Dup4 skipped (32, 60, 2560)
# Batch136 Dup4 skipped (32, 60, 2560)
# Batch137 Dup4 skipped (32, 60, 2560)
# Batch140 Dup4 skipped (32, 60, 2560)
# Batch139 Dup4 skipped (32, 60, 2560)
# Batch138 Dup4 skipped (32, 60, 2560)
# Batch141 Dup4 skipped (32, 60, 2560)
# Batch142 Dup4 skipped (32, 60, 2560)
# Batch143 Dup4 skipped (32, 60, 2560)
# Batch144 Dup4 skipped (32, 60, 2560)
# Batch145 Dup4 skipped (32, 60, 2560)
# Batch146 Dup4 skipped (32, 60, 2560)
# Batch166 Dup4 skipped (32, 60, 2560)
# Batch163 Dup4 skipped (32, 60, 2560)
# Batch165 Dup4 skipped (32, 60, 2560)
# Batch150 Dup4 skipped (32, 60, 2560)
# Batch156 Dup4 skipped (32, 60, 2560)
# Batch164 Dup4 skipped (32, 60, 2560)
# Batch158 Dup4 skipped (32, 60, 2560)
# Batch157 Dup4 skipped (32, 60, 2560)
# Batch152 Dup4 skipped (32, 60, 2560)
# Batch162 Dup4 skipped (32, 60, 2560)
# Batch161 Dup4 skipped (32, 60, 2560)
# Batch147 Dup4 skipped (32, 60, 2560)
# Batch148 Dup4 skipped (32, 60, 2560)
# Batch149 Dup4 skipped (32, 60, 2560)
# Batch151 Dup4 skipped (32, 60, 2560)
# Batch153 Dup4 skipped (32, 60, 2560)
# Batch154 Dup4 skipped (32, 60, 2560)
# Batch155 Dup4 skipped (32, 60, 2560)
# Batch159 Dup4 skipped (32, 60, 2560)
# Batch160 Dup4 skipped (32, 60, 2560)
