# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import numpy as np

from tensorflow.keras.applications import EfficientNetB7

import tensorflow.keras
from tensorflow.keras import applications
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *

# %%
validation_video_path = '/content/drive/MyDrive/4levelClassification/validate/'
test_video_path = '/content/drive/MyDrive/4levelClassification/Test/'
validate_nparray_path = '/content/drive/MyDrive/4levelClassification/validate_nparray/'
test_nparray_path = '/content/drive/MyDrive/4levelClassification/test_nparray/'
saved_nparray_validate_path = '/content/drive/MyDrive/4levelClassification/validate_nparray/data/'
saved_nparray_test_path = '/content/drive/MyDrive/4levelClassification/test_nparray/data/'

img_height , img_width = 600, 600  # dimension of each frame in video
seq_len = 60 #the number of images we pass as one sequence (only 70 frames per video) -more frames/ better results/ computationally expensive

classes = [0, 1, 2, 3]

# %%
def conv_base():
    feature_extractor =  tensorflow.keras.applications.EfficientNetB7(input_shape=(img_height,img_width,3),
                              include_top=False, weights='imagenet',pooling="avg")

    preprocess_input = tensorflow.keras.applications.efficientnet.preprocess_input
    inputs = tensorflow.keras.Input((img_height, img_width, 3))
    preprocessed = preprocess_input(inputs)

    outputs = feature_extractor(preprocessed)
    return tensorflow.keras.Model(inputs, outputs, name="conv_base")

conv_base = conv_base()
conv_base.summary()
# Out:
# Model: "conv_base"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 600, 600, 3)]     0
#
#  efficientnetb7 (Functional)  (None, 2560)             64097687
#
# =================================================================
# Total params: 64,097,687
# Trainable params: 63,786,960
# Non-trainable params: 310,727
# _________________________________________________________________

# %%
part1=0
part2=60
part3=120
part4=180
part5=240
currentPart = -1
def frames_extraction(video_path):

    frames_list = []

    #creating an object by capturing the given video
    #This object can be used to read frames from the captured video
    vidObj = cv2.VideoCapture(video_path)

    #Counter variable - will be incrementing upto the seq_len
    seqCount = 1
    #skipCount = 2
    defect = 0
    successCount = 0
    start = 0

    #The count variable ensures that the number of extracted frames should be equal to the seq_len
    while seqCount <= 60:

        #Reading one frame at a time from the video, it returns status (success) and the actual frame (image)
        success, image = vidObj.read()
        #print(success)
        #If it is not able to read the frame properly then success = 0, and code will jump to else part
        #if success and skipCount == 0:
        if success and start>currentPart:
            image = cv2.resize(image, (img_height, img_width))
            frames_list.append(image)
            seqCount += 1
            #skipCount = 2
            successCount += 1


        elif success and start<=currentPart:
            start +=1
        #elif skipCount > 0:
        #  skipCount -= 1

        elif (defect + seqCount) >=300:
          break

        else:
            '''Defect frame will not be added to list of frames and if number of extracted frames is less than the seq_len, video will be rejected, in next section'''
            defect += 1
            print("Defected frame at ", defect, " ", video_path)

    print(start)
    print("Defected", defect)
    print("successCount", successCount)
    frames = np.asarray(frames_list)
    vidObj.release()
    return frames

# %%
def create_Data(batch_dir):
    X = []
    Y = []

    classes_list = os.listdir(batch_dir)
    print(classes_list)

    for c in classes_list:
        print(c)
        # creating the list of videos for the current class
        files_list = os.listdir(os.path.join(batch_dir, c))
        # we’ll pass videos one by one for frames extraction
        for f in files_list:
            #extracting the frames from the given video
            video_path = (os.path.join(os.path.join(batch_dir, c), f))
            #print(video_path)
            frames = frames_extraction(video_path)
            # Check whether the number of frames is equal to the seq_len, if yes -> process, otherwise reject the current video
            if len(frames) == seq_len:
                print(np.asarray(frames).shape)
                #appending the sequence of frames to the input list X
                X.append(conv_base.predict(frames))
                #X.append(frames)
                #we are creating one hot encoding for target variable
                #create the list y of length number of classes, where each element is 0
                y = [0]*len(classes)
                #We find the index of current class c in the classes list and making corresponding element 1 in y
                y[classes.index(int(c))] = 1
                #Now we append the list y into Y
                Y.append(y)

    X = np.asarray(X)
    Y = np.asarray(Y)
    return X, Y

# %%
#validate all parts
parts = ["part1", "part2", "part3", "part4", "part5"]
parts_value = [part1, part2, part3, part4, part5]
batches_list = os.listdir(validation_video_path)
print("batches_list", batches_list)
saved_batches = os.listdir(saved_nparray_validate_path) #no need for this if we have good reources
print("saved_batches", saved_batches)
counter = 0
for i in range(5):
        if parts[i]+".npy" in saved_batches: #no need for the if we have no resources
          skippedBatch = np.load(os.path.join(validate_nparray_path, "data" , parts[i]+".npy"))
          print(parts[i], "skipped", skippedBatch.shape)
          continue
        currentPart = parts_value[i]
        print("currentPart ", parts[i])
        x_batch, y_batch = create_Data(validation_video_path)
        x_batch = np.asarray(x_batch)
        y_batch = np.asarray(y_batch)
        np.save(os.path.join(validate_nparray_path, "data", parts[i]), x_batch)
        np.save(os.path.join(validate_nparray_path, "label", parts[i]), y_batch)

        counter += 1
        print(counter)
# Out:
# batches_list ['2', '3', '1', '0']
# saved_batches ['part1.npy', 'part2.npy', 'part3.npy', 'part4.npy', '.ipynb_checkpoints']
# part1 skipped (1429, 60, 2560)
# part2 skipped (1429, 60, 2560)
# part3 skipped (1429, 60, 2560)
# part4 skipped (1429, 60, 2560)
# currentPart  part5
# ['2', '3', '1', '0']
# 2
# Defected frame at  1   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  2   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  3   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  4   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  5   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  6   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  7   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  8   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  9   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  10   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  11   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  12   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  13   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  14   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  15   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  16   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  17   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  18   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  19   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  20   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  21   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  22   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  23   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  24   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  25   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  26   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  27   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  28   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  29   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  30   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  31   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  32   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  33   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  34   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  35   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  36   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  37   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  38   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  39   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  40   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  41   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  42   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  43   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  44   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  45   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  46   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  47   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  48   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  49   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  50   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  51   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  52   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  53   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  54   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  55   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  56   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  57   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  58   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  59   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  60   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  61   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  62   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  63   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  64   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  65   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  66   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  67   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  68   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  69   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  70   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  71   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  72   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  73   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  74   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  75   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  76   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  77   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  78   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  79   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  80   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  81   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  82   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  83   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  84   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  85   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  86   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  87   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  88   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  89   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  90   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  91   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  92   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  93   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  94   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  95   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  96   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  97   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  98   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  99   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  100   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  101   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  102   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  103   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  104   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  105   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  106   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  107   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  108   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  109   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  110   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  111   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  112   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  113   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  114   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  115   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  116   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  117   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  118   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  119   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  120   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  121   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  122   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  123   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  124   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  125   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  126   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  127   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  128   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  129   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  130   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  131   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  132   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  133   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  134   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  135   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  136   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  137   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  138   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  139   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  140   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  141   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  142   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  143   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  144   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  145   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  146   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  147   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  148   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  149   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  150   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  151   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  152   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  153   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  154   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  155   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  156   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  157   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  158   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  159   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  160   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  161   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  162   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  163   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  164   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  165   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  166   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  167   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  168   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  169   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  170   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  171   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  172   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  173   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  174   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  175   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  176   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  177   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  178   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  179   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  180   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  181   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  182   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  183   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  184   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  185   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  186   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  187   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  188   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  189   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  190   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  191   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  192   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  193   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  194   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  195   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  196   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  197   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  198   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  199   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  200   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  201   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  202   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  203   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  204   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  205   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  206   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  207   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  208   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  209   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  210   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  211   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  212   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  213   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  214   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  215   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  216   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  217   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  218   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  219   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  220   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  221   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  222   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  223   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  224   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  225   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  226   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  227   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  228   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  229   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  230   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  231   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  232   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  233   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  234   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  235   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  236   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  237   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at  238   /content/drive/MyDrive/4levelClassification/validate/2/5564630143.avi
# Defected frame at
/content/drive/MyDrive/4levelClassification/validate/2/5564630150.avi
# Defected frame at  137   /content/drive/MyDrive/4levelClassification/validate/2/5564630150.avi
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-7025e3c0fa82> in <module>()
#      14         currentPart = parts_value[i]
#      15         print("currentPart ", parts[i])
# ---> 16         x_batch, y_batch = create_Data(validation_video_path)
#      17         x_batch = np.asarray(x_batch)
#      18         y_batch = np.asarray(y_batch)
#
# <ipython-input-13-243b3404eae8> in create_Data(batch_dir)
#      15             video_path = (os.path.join(os.path.join(batch_dir, c), f))
#      16             #print(video_path)
# ---> 17             frames = frames_extraction(video_path)
#      18             # Check whether the number of frames is equal to the seq_len, if yes -> process, otherwise reject the current video
#      19             if len(frames) == seq_len:
#
# <ipython-input-12-7623b027ca90> in frames_extraction(video_path)
#      24
#      25         #Reading one frame at a time from the video, it returns status (success) and the actual frame (image)
# ---> 26         success, image = vidObj.read()
#      27         #print(success)
#      28         #If it is not able to read the frame properly then success = 0, and code will jump to else part
#
# KeyboardInterrupt:

# %%
'''
#test all parts
parts = ["part1", "part2", "part3", "part4", "part5"]
parts_value = [part1, part2, part3, part4, part5]
batches_list = os.listdir(test_video_path)
print("batches_list", batches_list)
saved_batches = os.listdir(saved_nparray_test_path) #no need for this if we have good reources
print("saved_batches", saved_batches)
counter = 0
for i in range(5):
        if parts[i]+".npy" in saved_batches: #no need for the if we have no resources
          skippedBatch = np.load(os.path.join(test_nparray_path, "data" , parts[i]+".npy"))
          print(parts[i], "skipped", skippedBatch.shape)
          continue
        currentPart = parts_value[i]
        print("currentPart ", parts[i])
        x_batch, y_batch = create_Data(test_video_path)
        x_batch = np.asarray(x_batch)
        y_batch = np.asarray(y_batch)
        np.save(os.path.join(test_nparray_path, "data", parts[i]), x_batch)
        np.save(os.path.join(test_nparray_path, "label", parts[i]), y_batch)

        counter += 1
        print(counter)
'''
# Out:
# '\n#test all parts\nparts = ["part1", "part2", "part3", "part4", "part5"]\nparts_value = [part1, part2, part3, part4, part5]\nbatches_list = os.listdir(validation_video_path)\nprint("batches_list", batches_list)\nsaved_batches = os.listdir(saved_nparray_test_path) #no need for this if we have good reources\nprint("saved_batches", saved_batches)\ncounter = 0\nfor i in range(5):\n        if parts[i]+".npy" in saved_batches: #no need for the if we have no resources\n          skippedBatch = np.load(os.path.join(test_nparray_path, "data" , parts[i]+".npy"))\n          print(parts[i], "skipped", skippedBatch.shape)\n          continue\n        currentPart = parts_value[i]    \n        print("currentPart ", parts[i])\n        x_batch, y_batch = create_Data(test_video_path)\n        x_batch = np.asarray(x_batch)\n        y_batch = np.asarray(y_batch)\n        np.save(os.path.join(test_nparray_path, "data", parts[i]), x_batch)\n        np.save(os.path.join(test_nparray_path, "label", parts[i]), y_batch)\n\n        counter += 1\n        print(counter)\n'

# %%
validation_data = np.load("/content/drive/MyDrive/4levelClassification/validate_nparray/data/part4.npy")
validation_label = np.load("/content/drive/MyDrive/4levelClassification/validate_nparray/label/part4.npy")
print(validation_data.shape)
print(validation_label.shape)
'''
test_data = np.load(test_nparray_path + "data" +"part1.npy")
test_label = np.load(test_nparray_path + "label" +"part1.npy")
print(test_data.shape)
print(test_label.shape)
'''
# Out:
# (1429, 60, 2560)
# (1429, 4)
# '\ntest_data = np.load(test_nparray_path + "data" +"part1.npy")\ntest_label = np.load(test_nparray_path + "label" +"part1.npy")\nprint(test_data.shape)\nprint(test_label.shape)\n'
